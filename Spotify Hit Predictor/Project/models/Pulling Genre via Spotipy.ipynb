# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
df = pd.read_csv('./data/final.csv')

# %%
df.head()
# Out:
#                                             track           artist  \
# 0                                     Misty Roses  Astrud Gilberto
# 1                                      Never Ever       All Saints
# 2                                     Soul Sermon    Gregg Karukas
# 3                       Clarinet Marmalade - Live    Alton Purnell
# 4  До смерті і довше - Drum & Base and Rock Remix         Skryabin
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:50RBM1j1Dw7WYmsGsWg9Tm         0.527   0.316    1   -15.769
# 1  spotify:track:5FTz9qQ94PyUHETyAyfYZN         0.738   0.541    1    -5.485
# 2  spotify:track:6m24oe3lk1UMxq9zq4iPFi         0.736   0.419    0   -10.662
# 3  spotify:track:5FOXuiLI6knVtgMUjWKj6x         0.565   0.594    5   -13.086
# 4  spotify:track:6CxyIPTqSPvAPXfrIZczs4         0.513   0.760    4   -10.077
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
client_id = 'd49aa74a69754ddfbc0b5c45f1bb516a'
client_secret = '0a912fbedb474f4b83431b34e6db628f'

client_credentials = SpotifyClientCredentials(
    client_id=client_id, 
    client_secret=client_secret,
)

sp = spotipy.Spotify(client_credentials_manager=client_credentials)
print(sp)

# %%
def get_genre(track_uri):
    track_info = sp.track(track_uri)
    genre = track_info['album'].get('genres', ['Unknown'])[0]
    return genre

def get_genres(df):
    genres = []
    for index, row in df.iterrows():
        track_uri = row['uri']
        genre = get_genre(track_uri)
        genres.append(genre)
    return genres

# example usage
song_df = pd.read_csv('./data/final.csv')
genres = get_genres(song_df)
print(genres)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xc/cty1r15d6z5gmv0xj4b8q_wr0000gn/T/ipykernel_82244/1836082815.py in <module>
#      24 # example usage
#      25 song_df = pd.read_csv('./data/final.csv')
# ---> 26 genres = get_genres(song_df)
#      27 print(genres)
#
# /var/folders/xc/cty1r15d6z5gmv0xj4b8q_wr0000gn/T/ipykernel_82244/1836082815.py in get_genres(df)
#      18     for index, row in df.iterrows():
#      19         track_uri = row['uri']
# ---> 20         genre = get_genre(track_uri)
#      21         genres.append(genre)
#      22     return genres
#
# /var/folders/xc/cty1r15d6z5gmv0xj4b8q_wr0000gn/T/ipykernel_82244/1836082815.py in get_genre(track_uri)
#      10
#      11 def get_genre(track_uri):
# ---> 12     track_info = sp.track(track_uri)
#      13     genre = track_info['album'].get('genres', ['Unknown'])[0]
#      14     return genre
#
# ...

# %%
def get_genre(track_uri):
    track_info = sp.track(track_uri.split(":")[2])
    print("track: ",track_info)
    genre = track_info['album'].get('genres', ['Unknown'])[0]
    return genre

def get_genres(df):
    genres = []
    for index, row in df.iterrows():
        print("row: ", row['uri'])
        track_uri = row['uri']
        print("Get genre: ")
        genre = get_genre(track_uri)
        genres.append(genre)
        print("genres: ",genre)
        break
    return genres

# example usage
song_df = pd.read_csv('./data/final.csv')
genres = get_genres(song_df)
print(genres)

# %%
for index, row in df.iterrows():
    print("row: ", row['uri'])
    track = sp.track(row['uri'])
    print(track)
    if index == 1:
        break
