# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('./data/final.csv')

# %%
df.head()
# Out:
#                                             track           artist  \
# 0                                     Misty Roses  Astrud Gilberto
# 1                                      Never Ever       All Saints
# 2                                     Soul Sermon    Gregg Karukas
# 3                       Clarinet Marmalade - Live    Alton Purnell
# 4  До смерті і довше - Drum & Base and Rock Remix         Skryabin
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:50RBM1j1Dw7WYmsGsWg9Tm         0.527   0.316    1   -15.769
# 1  spotify:track:5FTz9qQ94PyUHETyAyfYZN         0.738   0.541    1    -5.485
# 2  spotify:track:6m24oe3lk1UMxq9zq4iPFi         0.736   0.419    0   -10.662
# 3  spotify:track:5FOXuiLI6knVtgMUjWKj6x         0.565   0.594    5   -13.086
# 4  spotify:track:6CxyIPTqSPvAPXfrIZczs4         0.513   0.760    4   -10.077
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
df.replace({0: 'Flop', 1: 'Bop'}, inplace=True)

# %%
df.head()
# Out:
#                                             track           artist  \
# 0                                     Misty Roses  Astrud Gilberto
# 1                                      Never Ever       All Saints
# 2                                     Soul Sermon    Gregg Karukas
# 3                       Clarinet Marmalade - Live    Alton Purnell
# 4  До смерті і довше - Drum & Base and Rock Remix         Skryabin
#
#                                     uri danceability energy   key  loudness  \
# 0  spotify:track:50RBM1j1Dw7WYmsGsWg9Tm        0.527  0.316   Bop   -15.769
# 1  spotify:track:5FTz9qQ94PyUHETyAyfYZN        0.738  0.541   Bop    -5.485
# 2  spotify:track:6m24oe3lk1UMxq9zq4iPFi        0.736  0.419  Flop   -10.662
# 3  spotify:track:5FOXuiLI6knVtgMUjWKj6x        0.565  0.594     5   -13.086
# 4  spotify:track:6CxyIPTqSPvAPXfrIZczs4        0.513   0.76     4   -10.077
#
#   mode speechiness acousticness instrumentalness  liveness valence    tempo  \
# ...

# %%
df.dtypes
# Out:
# track                object
# artist               object
# uri                  object
# danceability         object
# energy               object
# key                  object
# loudness            float64
# mode                 object
# speechiness          object
# acousticness         object
# instrumentalness     object
# liveness            float64
# valence              object
# tempo                object
# duration_ms           int64
# time_signature       object
# chorus_hit           object
# sections             object
# target               object
# Year                float64
# dtype: object

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.dtypes
# Out:
# track                object
# artist               object
# uri                  object
# danceability         object
# energy               object
# key                  object
# loudness            float64
# mode                 object
# speechiness          object
# acousticness         object
# instrumentalness     object
# liveness            float64
# valence              object
# tempo                object
# duration_ms           int64
# time_signature       object
# chorus_hit           object
# sections             object
# target               object
# Year                  int64
# dtype: object

# %%
df.head()
# Out:
#                                             track           artist  \
# 0                                     Misty Roses  Astrud Gilberto
# 1                                      Never Ever       All Saints
# 2                                     Soul Sermon    Gregg Karukas
# 3                       Clarinet Marmalade - Live    Alton Purnell
# 4  До смерті і довше - Drum & Base and Rock Remix         Skryabin
#
#                                     uri danceability energy   key  loudness  \
# 0  spotify:track:50RBM1j1Dw7WYmsGsWg9Tm        0.527  0.316   Bop   -15.769
# 1  spotify:track:5FTz9qQ94PyUHETyAyfYZN        0.738  0.541   Bop    -5.485
# 2  spotify:track:6m24oe3lk1UMxq9zq4iPFi        0.736  0.419  Flop   -10.662
# 3  spotify:track:5FOXuiLI6knVtgMUjWKj6x        0.565  0.594     5   -13.086
# 4  spotify:track:6CxyIPTqSPvAPXfrIZczs4        0.513   0.76     4   -10.077
#
#   mode speechiness acousticness instrumentalness  liveness valence    tempo  \
# ...

# %%
df.rename(columns={'Year': 'decade'}, inplace=True)

# %%
df.head()
# Out:
#                                             track           artist  \
# 0                                     Misty Roses  Astrud Gilberto
# 1                                      Never Ever       All Saints
# 2                                     Soul Sermon    Gregg Karukas
# 3                       Clarinet Marmalade - Live    Alton Purnell
# 4  До смерті і довше - Drum & Base and Rock Remix         Skryabin
#
#                                     uri danceability energy   key  loudness  \
# 0  spotify:track:50RBM1j1Dw7WYmsGsWg9Tm        0.527  0.316   Bop   -15.769
# 1  spotify:track:5FTz9qQ94PyUHETyAyfYZN        0.738  0.541   Bop    -5.485
# 2  spotify:track:6m24oe3lk1UMxq9zq4iPFi        0.736  0.419  Flop   -10.662
# 3  spotify:track:5FOXuiLI6knVtgMUjWKj6x        0.565  0.594     5   -13.086
# 4  spotify:track:6CxyIPTqSPvAPXfrIZczs4        0.513   0.76     4   -10.077
#
#   mode speechiness acousticness instrumentalness  liveness valence    tempo  \
# ...

# %%
df.to_csv('./data/tableau.csv', index=False)
